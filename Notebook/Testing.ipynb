# %%
import os
os.chdir(r'C:\Users\tiend\OneDrive\Documents\ASU MSBA 2024\CIS515 AI and Data Analytics Strategy\Final Project\Easter2\src')
from predict import test_on_iam
from data_loader import data_loader
import config

# %%
# checkpoint_path = "../weights/saved_checkpoint.hdf5"
# checkpoint_path = r'C:\Users\tiend\OneDrive\Documents\ASU MSBA 2024\CIS515 AI and Data Analytics Strategy\Final Project\Easter2\saved weights\saved_checkpoint.hdf5'
checkpoint_path = r'C:\Users\tiend\OneDrive\Documents\ASU MSBA 2024\CIS515 AI and Data Analytics Strategy\Final Project\Easter2\weights\saved_weights.weights.h5'

# %% [markdown]
# ## Check CER on validation set

# %%
# val_char_error, val_total_chars = test_on_iam(show=False, partition="validation", checkpoint=checkpoint_path, uncased=True)

# %% [markdown]
# ## Check CER on Test Set

# %%
test_char_error, test_total_chars = test_on_iam(show=False, partition="test", checkpoint=checkpoint_path, uncased=False)
# Out:
# loading metdata...
# loading checkpoint...
# calculating results...
# Using Test Partition
# Number of Samples :  2915
#   0%|          | 0/2915 [00:00<?, ?it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 1/2915 [00:00<39:38,  1.22it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 2/2915 [00:00<19:38,  2.47it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 3/2915 [00:01<13:20,  3.64it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 4/2915 [00:01<10:20,  4.69it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 5/2915 [00:01<09:09,  5.30it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 6/2915 [00:01<08:15,  5.87it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 7/2915 [00:01<07:25,  6.53it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 8/2915 [00:01<06:51,  7.06it/s]
# type of img = <class 'numpy.ndarray'>
# ...
#   0%|          | 9/2915 [00:01<06:30,  7.45it/s]
# ...

# %%
print(test_char_error)
# Out:
# 15653

# %%
print(test_total_chars)
# Out:
# 125314

# %%
test_char_error / test_total_chars * 100
